# %% [markdown]
# # Pump it Up

# %% [markdown]
# *Please note that we expect
# to see a comparison of multiple approaches to solving the issue from different partners in the team.*

# %% [markdown]
# Competition Link Here

# %% [markdown]
# amount_tsh - Total static head (amount water available to waterpoint): the amount of water the pump can push or provide, measured in height (meters). It's a way to gauge the water capacity or pressure the pump can handle or is dealing with.
# date_recorded - The date the row was entered
# funder - Who funded the well
# gps_height - Altitude of the well
# installer - Organization that installed the well
# longitude - GPS coordinate
# latitude - GPS coordinate
# wpt_name - Name of the waterpoint if there is one
# num_private -
# basin - Geographic water basin
# subvillage - Geographic location
# region - Geographic location
# region_code - Geographic location (coded)
# district_code - Geographic location (coded)
# lga - Geographic location
# ward - Geographic location
# population - Population around the well
# public_meeting - True/False, whether a public meeting about this water pump has taken place?
# recorded_by - Group entering this row of data
# scheme_management - Who operates the waterpoint
# scheme_name - Who operates the waterpoint
# permit - If the waterpoint is permitted
# construction_year - Year the waterpoint was constructed
# extraction_type - The kind of extraction the waterpoint uses
# extraction_type_group - The kind of extraction the waterpoint uses
# extraction_type_class - The kind of extraction the waterpoint uses
# management - How the waterpoint is managed
# management_group - How the waterpoint is managed
# payment - What the water costs
# payment_type - What the water costs
# water_quality - The quality of the water
# quality_group - The quality of the water
# quantity - The quantity of water
# quantity_group - The quantity of water
# source - The source of the water
# source_type - The source of the water
# source_class - The source of the water
# waterpoint_type - The kind of waterpoint
# waterpoint_type_group - The kind of waterpoint

# %% [markdown]
# Imputation Progress

# %% [markdown]
# ## Import Data & Data Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import MultipleLocator
# !pip install autoimpute
# Out:
# Collecting autoimpute
#   Downloading autoimpute-0.14.1-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /shared-libs/python3.11/py/lib/python3.11/site-packages (from autoimpute) (1.26.1)
# Requirement already satisfied: scipy in /shared-libs/python3.11/py/lib/python3.11/site-packages (from autoimpute) (1.11.3)
# Requirement already satisfied: pandas in /shared-libs/python3.11/py/lib/python3.11/site-packages (from autoimpute) (2.1.4)
# Collecting statsmodels (from autoimpute)
#   Downloading statsmodels-0.14.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 110.5 MB/s eta 0:00:00
# Collecting xgboost (from autoimpute)
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /shared-libs/python3.11/py/lib/python3.11/site-packages (from autoimpute) (1.3.1)
# Collecting pymc (from autoimpute)
#   Downloading pymc-5.14.0-py3-none-any.whl (480 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 78.2 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /shared-libs/python3.11/py/lib/python3.11/site-packages (from autoimpute) (0.13.2)
# Requirement already satisfied: missingno in /root/venv/lib/python3.11/site-packages (from autoimpute) (0.5.2)
# Requirement already satisfied: matplotlib in /shared-libs/python3.11/py/lib/python3.11/site-packages (from missingno->autoimpute) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from pandas->autoimpute) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pandas->autoimpute) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pandas->autoimpute) (2024.1)
# Collecting arviz>=0.13.0 (from pymc->autoimpute)
#   Downloading arviz-0.18.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.2.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pymc->autoimpute) (5.3.1)
# Collecting cloudpickle (from pymc->autoimpute)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Collecting pytensor<2.21,>=2.20 (from pymc->autoimpute)
#   Downloading pytensor-2.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 93.5 MB/s eta 0:00:00
# Collecting rich>=13.7.1 (from pymc->autoimpute)
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 48.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pymc->autoimpute) (4.8.0)
# Requirement already satisfied: joblib>=1.1.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-learn->autoimpute) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-learn->autoimpute) (3.2.0)
# Collecting patsy>=0.5.6 (from statsmodels->autoimpute)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 51.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from statsmodels->autoimpute) (23.2)
# Requirement already satisfied: setuptools>=60.0.0 in /root/venv/lib/python3.11/site-packages (from arviz>=0.13.0->pymc->autoimpute) (65.5.0)
# Collecting dm-tree>=0.1.8 (from arviz>=0.13.0->pymc->autoimpute)
#   Downloading dm_tree-0.1.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 32.5 MB/s eta 0:00:00
# Collecting xarray>=2022.6.0 (from arviz>=0.13.0->pymc->autoimpute)
#   Downloading xarray-2024.3.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 100.6 MB/s eta 0:00:00
# Collecting h5netcdf>=1.0.2 (from arviz>=0.13.0->pymc->autoimpute)
#   Downloading h5netcdf-1.3.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 13.5 MB/s eta 0:00:00
# Collecting xarray-einstats>=0.3 (from arviz>=0.13.0->pymc->autoimpute)
#   Downloading xarray_einstats-0.7.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->missingno->autoimpute) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->missingno->autoimpute) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->missingno->autoimpute) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->missingno->autoimpute) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->missingno->autoimpute) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->missingno->autoimpute) (3.1.1)
# Requirement already satisfied: six in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels->autoimpute) (1.16.0)
# Requirement already satisfied: filelock in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pytensor<2.21,>=2.20->pymc->autoimpute) (3.12.4)
# Collecting etuples (from pytensor<2.21,>=2.20->pymc->autoimpute)
#   Downloading etuples-0.3.9.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting logical-unification (from pytensor<2.21,>=2.20->pymc->autoimpute)
#   Downloading logical-unification-0.4.6.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Collecting miniKanren (from pytensor<2.21,>=2.20->pymc->autoimpute)
#   Downloading miniKanren-1.0.3.tar.gz (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cons (from pytensor<2.21,>=2.20->pymc->autoimpute)
#   Downloading cons-0.4.6.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Collecting markdown-it-py>=2.2.0 (from rich>=13.7.1->pymc->autoimpute)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from rich>=13.7.1->pymc->autoimpute) (2.16.1)
# Requirement already satisfied: h5py in /shared-libs/python3.11/py/lib/python3.11/site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc->autoimpute) (3.10.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc->autoimpute)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: toolz in /shared-libs/python3.11/py/lib/python3.11/site-packages (from logical-unification->pytensor<2.21,>=2.20->pymc->autoimpute) (0.12.0)
# Collecting multipledispatch (from logical-unification->pytensor<2.21,>=2.20->pymc->autoimpute)
#   Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Building wheels for collected packages: cons, logical-unification, etuples, miniKanren
#   Building wheel for cons (setup.py) ... done
#   Created wheel for cons: filename=cons-0.4.6-py3-none-any.whl size=9100 sha256=3541a4ffd81d143b9cfa285b954e75e529751d97627febf93d2f8464e38549a9
#   Stored in directory: /root/.cache/pip/wheels/95/8f/45/fe0a5b5e232401da571d514eb545833fbe220993ac8336c94e
#   Building wheel for logical-unification (setup.py) ... done
#   Created wheel for logical-unification: filename=logical_unification-0.4.6-py3-none-any.whl size=13911 sha256=e2cb686caac8e6a9c1f8471cc097cf4824f46763952fc0b57879b8969861fe05
#   Stored in directory: /root/.cache/pip/wheels/b8/34/a9/c11a21ef1f1b6d2e5ae518dd5d28c0bd2b131c5d6e5d4417c3
#   Building wheel for etuples (setup.py) ... done
#   Created wheel for etuples: filename=etuples-0.3.9-py3-none-any.whl size=12618 sha256=df9369a776ac2ec9665ed511a548a0f5c2bc58fad4148ebadd8ba221d187b2af
#   Stored in directory: /root/.cache/pip/wheels/11/5a/ad/ebef6395e95b1dfd742afb44db6d92bd5e8921a572b9ff8618
#   Building wheel for miniKanren (setup.py) ... done
#   Created wheel for miniKanren: filename=miniKanren-1.0.3-py3-none-any.whl size=23911 sha256=26cadf52fe9c325852faed826eeb8dfc3145d1bef70ce484462f52258e2b6a65
#   Stored in directory: /root/.cache/pip/wheels/8d/86/58/7da4a186a7bb721885e4fb811a54b5a0065b0c624a5deb1259
# Successfully built cons logical-unification etuples miniKanren
# Installing collected packages: multipledispatch, dm-tree, patsy, mdurl, logical-unification, cloudpickle, xgboost, markdown-it-py, h5netcdf, cons, xarray, statsmodels, rich, etuples, xarray-einstats, miniKanren, pytensor, arviz, pymc, autoimpute
# Successfully installed arviz-0.18.0 autoimpute-0.14.1 cloudpickle-3.0.0 cons-0.4.6 dm-tree-0.1.8 etuples-0.3.9 h5netcdf-1.3.0 logical-unification-0.4.6 markdown-it-py-3.0.0 mdurl-0.1.2 miniKanren-1.0.3 multipledispatch-1.0.0 patsy-0.5.6 pymc-5.14.0 pytensor-2.20.0 rich-13.7.1 statsmodels-0.14.2 xarray-2024.3.0 xarray-einstats-0.7.0 xgboost-2.0.3
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Adding Data

# %%
#Reading Datasets
training_values = pd.read_csv('training_set_values.csv')

#Reading Dataset of pumps
training_labels = pd.read_csv('training_set_labels.csv')

#Reading Final test Values
test_values = pd.read_csv('test_set_values.csv')

all_df = pd.concat([training_values, test_values])
 

#Inner Merging these two datasets
training = pd.merge(training_values, training_labels, on='id', how='inner') 
training.rename(columns={'status_group': 'functional'}, inplace=True)

import sklearn
from sklearn.model_selection import train_test_split

X = training.drop(columns=['functional'])
y = training['functional']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
random_state=1, stratify=y)



coursework_progress = coursework_progress = pd.DataFrame({
    'Column Names': training.columns.tolist(), 
    "Taken Care Of": False, 
    "Imputation Techniques Tried": [[] for _ in training.columns],  
    "Imputation Technique Used": [None for _ in training.columns] 
})
imputed_df = pd.DataFrame()

def log_imputation(column_name: str, technique: str, final: bool):
    index = coursework_progress['Column Names'].tolist().index(column_name)
    coursework_progress.at[index, "Imputation Techniques Tried"].append(technique)
    if final:
        coursework_progress.at[index, "Taken Care Of"] = True
        coursework_progress.at[index, "Imputation Technique Used"] = technique

# %%
#Helper function
def check_impute_difference (feature, original_dataset, current_dataframe):
  original_dataset[feature].plot(kind='kde', )
  current_dataframe[feature].plot(kind='kde', style = "--")
  labels = ['Original Dataset', 'Current Dataframe']
  plt.legend(labels)
  plt.xlabel(feature)
  plt.show()

# %% [markdown]
# ## Sorting out Null Values

# %% [markdown]
# Many columns have rows who's values are null, but that Pandas does not recognise as these are not properly labelled (0 population for example is likely a NaN value)

# %%
#Globally replace NaN strings

dataframes = [X_train, X_test, test_values, all_df]

for df in dataframes:

    df.replace(inplace=True, to_replace='nan', value=np.nan)
    df.replace(inplace=True, to_replace='NaN', value=np.nan)
    df.replace(inplace=True, to_replace='NAN', value=np.nan)
    df.replace(inplace=True, to_replace='nAn', value=np.nan)
    df.replace(inplace=True, to_replace='Nan', value=np.nan)
    df.replace(inplace=True, to_replace='naN', value=np.nan)

    df['amount_tsh'].replace(inplace=True, to_replace=0, value=np.nan)
    df['date_recorded'] = pd.to_datetime(df['date_recorded'])
    df['gps_height'].replace(0, np.nan, inplace=True)
    df['longitude'].replace(0, np.nan, inplace=True)
    df['latitude'].replace(0, np.nan, inplace=True)
    df['population'].replace(0, np.nan, inplace=True)
    df['construction_year'].replace(0, np.nan, inplace=True)

# %% [markdown]
# ### Missing Data Analysis

# %% [markdown]
# The percentage of missing data varies from 0.6% to 98.7%

# %%
missing = round((all_df.isna().sum())/len(all_df)*100,1)
missing = missing.sort_values(ascending = False)
missing.head(15)
# Out:
# amount_tsh           70.1
# scheme_name          48.6
# population           36.1
# construction_year    35.0
# gps_height           34.5
# scheme_management     6.5
# installer             6.1
# funder                6.1
# public_meeting        5.6
# permit                5.1
# longitude             3.1
# subvillage            0.6
# latitude              0.0
# date_recorded         0.0
# id                    0.0
# dtype: float64

# %% [markdown]
# There is a clear relation between missing values in gps_height, population, construction_year and to some degree longitude. i.e. data is not missing at random.

# %%
import missingno as msno

# %%
sorted = all_df.sort_values('construction_year')
msno.matrix(sorted)
# Out:
# <Axes: >

# %% [markdown]
# Strong correlation in missingness

# %%
msno.heatmap(all_df)
# Out:
# <Axes: >

# %%
all_df[all_df['gps_height'] < all_df['gps_height'].quantile(0.05)]
# Out:
#           id  amount_tsh date_recorded              funder  gps_height  \
# 34     41583         NaN    2011-02-23                 NaN       -41.0
# 137    64062        30.0    2013-01-25                Lips        11.0
# 145    28669        50.0    2013-03-21                   0        12.0
# 148    53167         NaN    2013-01-24          Fini Water         1.0
# 152    60983         NaN    2013-03-16                   0       -15.0
# ...      ...         ...           ...                 ...         ...
# 14755   2811         NaN    2011-03-20       Islamic Found       -11.0
# 14767  64526         NaN    2013-01-24  Serikali Ya Kijiji         7.0
# 14811  14638       100.0    2011-03-26  Private Individual       -26.0
# 14817  33339        10.0    2011-03-05                 W.B       -31.0
# 14836  57539         NaN    2011-03-18               Amref        -7.0
#
#                 installer  longitude   latitude             wpt_name  \
# 34                    NaN  39.812912  -7.889986  Msikitini Wa Ijumaa
# 137                  LIPS  39.888981 -10.133632            Bondeni 1
# 145                     0  39.185710  -6.892593             Chekanao
# 148            Fini water  39.600234 -10.027721            Kwa Timba
# 152                     0  39.527114  -6.988748            Msikitini
# ...                   ...        ...        ...                  ...
# 14755                  Is  38.900477  -6.446184          Mwembeyanga
# 14767  Serikali ya kijiji  39.592783 -10.024897            Kwa Choka
# 14811                  Da  39.091240  -6.577881             Kapalila
# 14817                 DWE  39.188873  -7.888840             Mng'Ombe
# 14836               AMREF  39.140091  -7.477423           Nyamalonda
#
#        num_private  ... payment_type water_quality quality_group  \
# 34               0  ...    never pay         salty         salty
# 137              0  ...   per bucket          soft          good
# 145              0  ...   per bucket          soft          good
# 148              0  ...      unknown         salty         salty
# 152              0  ...    never pay         salty         salty
# ...            ...  ...          ...           ...           ...
# 14755            0  ...    never pay          soft          good
# 14767            0  ...      unknown          soft          good
# 14811            0  ...   per bucket          soft          good
# 14817            0  ...   per bucket         salty         salty
# 14836            0  ...    never pay          soft          good
#
#            quantity  quantity_group        source   source_type  source_class  \
# 34           enough          enough  shallow well  shallow well   groundwater
# 137    insufficient    insufficient  shallow well  shallow well   groundwater
# 145          enough          enough   machine dbh      borehole   groundwater
# 148          enough          enough   machine dbh      borehole   groundwater
# 152             dry             dry   machine dbh      borehole   groundwater
# ...             ...             ...           ...           ...           ...
# 14755        enough          enough  shallow well  shallow well   groundwater
# 14767        enough          enough        spring        spring   groundwater
# 14811        enough          enough         river    river/lake       surface
# 14817        enough          enough      hand dtw      borehole   groundwater
# 14836        enough          enough  shallow well  shallow well   groundwater
#
#           waterpoint_type waterpoint_type_group
# 34              hand pump             hand pump
# 137             hand pump             hand pump
# 145    communal standpipe    communal standpipe
# 148                 other                 other
# 152                 other                 other
# ...                   ...                   ...
# 14755           hand pump             hand pump
# 14767               other                 other
# 14811  communal standpipe    communal standpipe
# 14817           hand pump             hand pump
# 14836           hand pump             hand pump
#
# [2393 rows x 40 columns]

# %% [markdown]
# ### Tsh Values (amount water available to waterpoint)

# %%
#Proportion of rows with an amount of tsh_value = np.nan
number_of_zeros = all_df['amount_tsh'].isnull().sum().sum()
print(number_of_zeros / len(df.index) * 100)
# Out:
# 70.09966329966329

# %% [markdown]
# 70% of TSH values are missing. It could be a useful feature as it is essentially a representation of the power of a pump. Higher Power Pumps could indicate that it receives more maintenance as it is more "important", as shown below. The "mega pumps" > 120_000 are all functional.

# %%
sns.scatterplot(training, x='functional', y='amount_tsh')
plt.show()

# %% [markdown]
# However, seeing as the majority of the values are missing, for now we are going to remove it as imputation of such a scale would be risky and could confuse the model.

# %%
log_imputation('amount_tsh', 'removal', final=True)
for df in dataframes:
    df.drop(columns=['amount_tsh'], inplace=True)

# %% [markdown]
# ### Num Private

# %% [markdown]
# The num_private value has no description, and most of the values are zero. So we decide to drop it

# %%
all_df['num_private']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 14845    0
# 14846    0
# 14847    0
# 14848    0
# 14849    0
# Name: num_private, Length: 74250, dtype: int64

# %%
for df in dataframes:
    df.drop(columns=['num_private'], inplace=True, axis=1)
log_imputation('num_private', "removal", final=True)

# %% [markdown]
# ### Water Quality and Quality Group

# %% [markdown]
# Identified different spellings of "coloured" and "colored"

# %%
for df in dataframes:
    df.replace(inplace=True, to_replace="coloured", value="colored")

contingency_table = pd.crosstab(all_df['water_quality'], all_df['quality_group'])
sns.heatmap(contingency_table, annot=True, fmt="d")
plt.xlabel('Quality Group')
plt.ylabel('Water Quality')
plt.show()

# %% [markdown]
# This shows that the water_quality and water_group columns are essentially identical, but it uses a choice of different words. It seems reasonable to drop one of these two columns. Therefore we could merge these two columns by keeping the Quality group and appending the idea of 'soft' water to 'good' water

# %%
for df in dataframes:
    df['water_quality'].replace(to_replace='soft', value='soft (good)', inplace=True)
    df.drop(axis=1, columns=['quality_group'], inplace=True)
log_imputation('quality_group', 'removal', True)

# %% [markdown]
# ### Quantity and Quantity_Group

# %%
all_df["quantity_columns_same"] = all_df["quantity"] == all_df["quantity_group"]
print((all_df['quantity_columns_same'] == True).sum())
print((all_df['quantity_columns_same'] == False).sum())
# Out:
# 74250
# 0

# %% [markdown]
# We have shown that these two columns are identical, so it is safe to drop one of them, quantity_group is more descriptive so we are keeping the latter. Quantity is dropped.

# %%
for df in dataframes:
    df.drop(columns=['quantity'], inplace=True)
log_imputation('quantity', 'removal', True)

# %% [markdown]
# ### Waterpoint_type and Waterpoint_type_group

# %%
all_df["waterpoint_type_same"] = all_df["waterpoint_type"] == all_df["waterpoint_type_group"]
print((all_df['waterpoint_type_same'] == True).sum())
print((all_df['waterpoint_type_same'] == False).sum())
# Out:
# 66639
# 7611

# %%
all_df[all_df["waterpoint_type_same"] == False]
# Out:
#           id date_recorded                  funder  gps_height     installer  \
# 2      34310    2013-02-25            Lottery Club       686.0  World vision
# 3      67743    2013-01-28                  Unicef       263.0        UNICEF
# 5       9944    2011-03-13     Mkinga Distric Coun         NaN           DWE
# 53     32376    2011-08-01  Government Of Tanzania         NaN    Government
# 55     68724    2013-02-22                   Muwsa       766.0         MUWSA
# ...      ...           ...                     ...         ...           ...
# 14762   6867    2013-02-24                    Cdtf      1342.0           DWE
# 14765  64665    2013-02-11              World Bank      1260.0           DWE
# 14766  56279    2012-11-04  Government Of Tanzania         NaN           RWE
# 14773  35480    2011-04-11                   Water         NaN         Commu
# 14842  57731    2013-01-27                     Isf       808.0           DWE
#
#        longitude      latitude              wpt_name                    basin  \
# 2      37.460664 -3.821329e+00           Kwa Mahundi                  Pangani
# 3      38.486161 -1.115530e+01  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast
# 5      39.172796 -4.765587e+00                Tajiri                  Pangani
# 53           NaN -2.000000e-08                Polisi            Lake Victoria
# 55     37.348169 -3.356538e+00           Environment                  Pangani
# ...          ...           ...                   ...                      ...
# 14762  35.284436 -9.815460e+00             Kwa Festo               Lake Nyasa
# 14765  35.830211 -4.130413e+00      Bomba La Shuleni                 Internal
# 14766        NaN -2.000000e-08               Ofisini            Lake Victoria
# 14773  35.886779 -6.064549e+00              Zahanati              Wami / Ruvu
# 14842  29.740224 -4.882705e+00               Hongera          Lake Tanganyika
#
#          subvillage  ... payment_type  water_quality  quantity_group  \
# 2           Majengo  ...   per bucket    soft (good)          enough
# 3        Mahakamani  ...    never pay    soft (good)             dry
# 5       Moa/Mwereme  ...   per bucket          salty          enough
# 53           Center  ...      unknown        unknown             dry
# 55     Dhobi Street  ...   per bucket    soft (good)    insufficient
# ...             ...  ...          ...            ...             ...
# 14762       Muhande  ...   on failure    soft (good)          enough
# 14765        Gubali  ...   per bucket    soft (good)          enough
# 14766      Madukani  ...    never pay    soft (good)    insufficient
# 14773       Sokoine  ...    never pay    soft (good)             dry
# 14842     Mzizini A  ...      monthly    soft (good)          enough
#
#             source source_type  source_class              waterpoint_type  \
# 2              dam         dam       surface  communal standpipe multiple
# 3      machine dbh    borehole   groundwater  communal standpipe multiple
# 5            other       other       unknown  communal standpipe multiple
# 53     machine dbh    borehole   groundwater  communal standpipe multiple
# 55          spring      spring   groundwater  communal standpipe multiple
# ...            ...         ...           ...                          ...
# 14762        river  river/lake       surface  communal standpipe multiple
# 14765       spring      spring   groundwater  communal standpipe multiple
# 14766         lake  river/lake       surface  communal standpipe multiple
# 14773  machine dbh    borehole   groundwater  communal standpipe multiple
# 14842        river  river/lake       surface  communal standpipe multiple
#
#       waterpoint_type_group quantity_columns_same waterpoint_type_same
# 2        communal standpipe                  True                False
# 3        communal standpipe                  True                False
# 5        communal standpipe                  True                False
# 53       communal standpipe                  True                False
# 55       communal standpipe                  True                False
# ...                     ...                   ...                  ...
# 14762    communal standpipe                  True                False
# 14765    communal standpipe                  True                False
# 14766    communal standpipe                  True                False
# 14773    communal standpipe                  True                False
# 14842    communal standpipe                  True                False
#
# [7611 rows x 38 columns]

# %% [markdown]
# We have shown that waterpoint_type and waterpoint_type_group overlap, the only exception is certain waterpoint_type columns also have the suffix "multiple". Therefore it seems reasonsable to decide to remove the column "waterpoint_type_group" for now. Removing excessive columns helps prevent against overfitting as is better for performance and manageability of the data.

# %%
for df in dataframes:
    df.drop(columns=['waterpoint_type_group'], inplace=True)
log_imputation('waterpoint_type_group', 'removal', True)

# %% [markdown]
# ### Payment and Payment_type

# %% [markdown]
# Payment and Payment Type might be similar, so we are checking their differences

# %%
all_df["payment_same"] = all_df["payment"] == all_df["payment_type"]
print((all_df['payment_same'] == True).sum())
print((all_df['payment_same'] == False).sum())
# Out:
# 43175
# 31075

# %%
contingency_table = pd.crosstab(all_df['payment'], all_df['payment_type'])
sns.heatmap(contingency_table, annot=True, fmt="d")
plt.show()

# %% [markdown]
# The Heatmap shows that these two columns are the same but with different wording, we are choosing to keep the payment_type as the wording is a bit more concise

# %%
all_df[all_df["payment_same"] == False]
# Out:
#           id date_recorded                   funder  gps_height  \
# 0      69572    2011-03-14                    Roman      1390.0
# 2      34310    2013-02-25             Lottery Club       686.0
# 5       9944    2011-03-13      Mkinga Distric Coun         NaN
# 11     50409    2013-02-18                   Danida      1062.0
# 13     50495    2013-03-15  Lawatefuka Water Supply      1368.0
# ...      ...           ...                      ...         ...
# 14834  12592    2011-03-27                    Kirde         NaN
# 14837  71252    2013-02-10                    Tasaf      1241.0
# 14838   7869    2011-03-11                     Kkkt      2046.0
# 14842  57731    2013-01-27                      Isf       808.0
# 14846  18990    2011-03-21                     Hiap         NaN
#
#                   installer  longitude   latitude              wpt_name  \
# 0                     Roman  34.938093  -9.856322                  none
# 2              World vision  37.460664  -3.821329           Kwa Mahundi
# 5                       DWE  39.172796  -4.765587                Tajiri
# 11                   DANIDA  35.770258 -10.574175      Kwa Alid Nchimbi
# 13     Lawatefuka water sup  37.092574  -3.181783  Kwa John Izack Mmari
# ...                     ...        ...        ...                   ...
# 14834                   DWE  35.840727  -4.633272            Kwa Mrangi
# 14837                 TASAF  30.114667  -4.162845     Pentecoste Church
# 14838                 Commu  34.345525  -9.547077                  none
# 14842                   DWE  29.740224  -4.882705               Hongera
# 14846                  HIAP  37.451633  -5.350428      Bonde La Mkondoa
#
#                  basin    subvillage  ... payment_type  water_quality  \
# 0           Lake Nyasa      Mnyusi B  ...     annually    soft (good)
# 2              Pangani       Majengo  ...   per bucket    soft (good)
# 5              Pangani   Moa/Mwereme  ...   per bucket          salty
# 11          Lake Nyasa  Ngondombwito  ...   on failure    soft (good)
# 13             Pangani       Omarini  ...      monthly    soft (good)
# ...                ...           ...  ...          ...            ...
# 14834         Internal         Cheke  ...      monthly    soft (good)
# 14837  Lake Tanganyika        Minazi  ...     annually    soft (good)
# 14838       Lake Nyasa     Kipengele  ...     annually    soft (good)
# 14842  Lake Tanganyika     Mzizini A  ...      monthly    soft (good)
# 14846          Pangani       Mkondoa  ...     annually          salty
#
#        quantity_group        source   source_type  source_class  \
# 0              enough        spring        spring   groundwater
# 2              enough           dam           dam       surface
# 5              enough         other         other       unknown
# 11       insufficient  shallow well  shallow well   groundwater
# 13             enough        spring        spring   groundwater
# ...               ...           ...           ...           ...
# 14834    insufficient        spring        spring   groundwater
# 14837          enough   machine dbh      borehole   groundwater
# 14838          enough        spring        spring   groundwater
# 14842          enough         river    river/lake       surface
# 14846    insufficient  shallow well  shallow well   groundwater
#
#                    waterpoint_type quantity_columns_same waterpoint_type_same  \
# 0               communal standpipe                  True                 True
# 2      communal standpipe multiple                  True                False
# 5      communal standpipe multiple                  True                False
# 11                       hand pump                  True                 True
# 13              communal standpipe                  True                 True
# ...                            ...                   ...                  ...
# 14834           communal standpipe                  True                 True
# 14837                    hand pump                  True                 True
# 14838           communal standpipe                  True                 True
# 14842  communal standpipe multiple                  True                False
# 14846                    hand pump                  True                 True
#
#       payment_same
# 0            False
# 2            False
# 5            False
# 11           False
# 13           False
# ...            ...
# 14834        False
# 14837        False
# 14838        False
# 14842        False
# 14846        False
#
# [31075 rows x 38 columns]

# %%
for df in dataframes:
    df.drop(columns=['payment'], inplace=True, axis=1)
log_imputation('payment', 'removal', True)

# %% [markdown]
# ### Funder, Installer and Permit

# %% [markdown]
# The funder column is a bit problematic as it has a few inconsistencies: 0s to repalces NaN, as well as "No" which we assumes means there is no funder to report. We will be imputing the installer at this stage as well, as it shows a high correlation in missing values.

# %% [markdown]
# We are also removing trailing spaces for good measure in case to minimise unique values

# %%
for df in dataframes:
    print("Number of Unique Funders before: ", len(df['funder'].unique()))
    df['funder'].replace(inplace=True, to_replace='0', value=np.nan) #Few Values of 0
    df['funder'].replace(inplace=True, to_replace='No', value=np.nan) #Few values of 'no'
    df['funder'] = df['funder'].str.strip() #Strip trailing spaces
    print("Number of Unique Funders after: ", len(df['funder'].unique()))
# Out:
# Number of Unique Funders before:  1559
# Number of Unique Funders after:  1557
# Number of Unique Funders before:  1071
# Number of Unique Funders after:  1069
# Number of Unique Funders before:  980
# Number of Unique Funders after:  978
# Number of Unique Funders before:  2140
# Number of Unique Funders after:  2138

# %% [markdown]
# As funder is a category, we will first try mode imputation

# %%
df_train_funder = X_train.copy()
df_test_funder = X_test.copy()
df_test_values_funder = test_values.copy()

print("Percentage of null values funder: ", df_train_funder['funder'].isnull().mean())
print("Percentage of null values installer: ", df_train_funder['installer'].isnull().mean())
print("Percentage of null values permit: ", df_train_funder['permit'].isnull().mean())


mode_value = df_train_funder['funder'].mode()[0]  
print("Mode: ", mode_value)

# Correct way to replace NaN values with the mode
df_train_funder['funder'] = df_train_funder['funder'].fillna(mode_value)

# Selecting top funders from the original dataset for comparison
top_funders = X_train['funder'].value_counts().nlargest(20).index

fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)
X_train[X_train['funder'].isin(top_funders)]['funder'].value_counts(normalize=True).plot(kind='barh', ax=ax[0], title='Before Imputation')
df_train_funder[df_train_funder['funder'].isin(top_funders)]['funder'].value_counts(normalize=True).plot(kind='barh', ax=ax[1], title='After Imputation')

ax[0].set_xlabel('Proportion')
ax[0].set_ylabel('Funder')
ax[1].set_xlabel('Proportion')
plt.show()
# Out:
# Percentage of null values funder:  0.07592592592592592
# Percentage of null values installer:  0.06120731120731121
# Percentage of null values permit:  0.05117845117845118
# Mode:  Government Of Tanzania

# %% [markdown]
# Essentially, we are assuming that the 6% of missing funders are the Governemnt fo Tanzania, this doesn't feel very accurate and coud lead to issues. Therefore, we are going to be replacing missing values with a "missing" category; this will make the model create a missing category. This feels safer than simply making all the missing categories part of the "Government of Tanzania"

# %%
for df in dataframes:
    df['funder'].replace(np.nan, 'missing', inplace=True)
    df['installer'].replace(np.nan, 'missing', inplace=True)
    df['permit'].replace(np.nan, 'missing', inplace=True)

log_imputation('funder', 'missing category', final=True)
log_imputation('installer', 'missing category', final=True)
log_imputation('permit', 'missing category', final=True)

# %% [markdown]
# ### Subvillage

# %% [markdown]
# Subvillage is missing around 0.7%

# %% [markdown]
# ### Scheme Management

# %%
df_scheme = all_df.copy()

null_percentage = df_scheme['scheme_management'].isnull().mean() * 100

print("Percentage of null values in scheme management: {:.2f}%".format(null_percentage))

# Finding the top 20 'scheme_management' categories
top_schemes = df_scheme['scheme_management'].value_counts().nlargest(20).index

# Creating a figure and axes for plotting
fig, ax = plt.subplots()

# Plotting the distribution of 'scheme_management' for the top categories
df_scheme[df_scheme['scheme_management'].isin(top_schemes)]['scheme_management'].value_counts(normalize=True).plot(kind='barh', title='Before Imputation', ax=ax)

ax.set_xlabel('Proportion')
ax.set_ylabel('Scheme Management')
plt.show()
# Out:
# Percentage of null values in scheme management: 6.53%

# %% [markdown]
# As we can see, over 60% of the values of the values of scheme_management are 'VWC'; missing data analysis from earlier reveals that this column does not have any missingness correlation with any other column; it is safe to assume therefore that it is MAR. Therefore, we will choose to impute the value with the most column value: VWC

# %%
mode_value = df_scheme['scheme_management'].mode()[0]  
print("Mode of Scheme Management: ", mode_value)

# Correct way to replace NaN values with the mode
for df in dataframes:
    df['scheme_management'] = df['scheme_management'].fillna(mode_value)
# Out:
# Mode of Scheme Management:  VWC

# %% [markdown]
# ### Public Meeting

# %% [markdown]
# The public meeting column does not have any correlation with any other column. It is difficult to impute as it is a binary column which seems to have a specific meeting, and so we are going to make the decision of removing this column

# %%
for df in dataframes:
    df.drop(columns=['public_meeting'], inplace=True)
log_imputation('public_meeting', 'removal', final=True)

# %% [markdown]
# ### Scheme Name

# %%
print("Empty scheme names: ", (all_df['scheme_name'].isnull()).sum())
print("One letter scheme names: ", all_df[all_df['scheme_name'].str.len() == 1].shape[0])
# Out:
# Empty scheme names:  36052
# One letter scheme names:  2629

# %% [markdown]
# Looking through the column, we can see that almost half of all values are empty, and many values seem to be incomplete or inconsistent. Therefore, we are going to drop this column

# %%
for df in dataframes:
    df.drop(columns=['scheme_name'], inplace=True)
log_imputation('scheme_name', "removal", final=True)

# %% [markdown]
# ## Location (Gps_height, Longitude, Latitude)

# %%
print("Longitude: ", (all_df['longitude'].isnull()).sum())
print("Latitude: ", (all_df['latitude'].isnull()).sum()) 
print((all_df['gps_height'].isnull()).sum())
# Out:
# Longitude:  2269
# Latitude:  0
# 25649

# %% [markdown]
# Looking at the latitude and longitude

# %% [markdown]
# Latitude Null values are shown as `-2e-8` so we are replacing them by np.nan

# %%
all_df[all_df['longitude'].isnull()]
# Out:
#           id date_recorded                  funder  gps_height   installer  \
# 21      6091    2013-02-10                    Dwsp         NaN         DWE
# 53     32376    2011-08-01  Government Of Tanzania         NaN  Government
# 168    72678    2013-01-30                     Wvt         NaN         WVT
# 177    56725    2013-01-17             Netherlands         NaN         DWE
# 253    13042    2012-10-29                  Hesawa         NaN         DWE
# ...      ...           ...                     ...         ...         ...
# 14649  30454    2011-08-08               Nyamigogo         NaN       MASWI
# 14676  44766    2013-02-16                    Dwsp         NaN         DWE
# 14766  56279    2012-11-04  Government Of Tanzania         NaN         RWE
# 14831  37994    2012-10-26                  Hesawa         NaN         DWE
# 14841  64579    2012-10-26                    Dwsp         NaN         DWE
#
#        longitude      latitude                 wpt_name          basin  \
# 21           NaN -2.000000e-08                 Muungano  Lake Victoria
# 53           NaN -2.000000e-08                   Polisi  Lake Victoria
# 168          NaN -2.000000e-08             Wvt Tanzania  Lake Victoria
# 177          NaN -2.000000e-08  Kikundi Cha Wakina Mama  Lake Victoria
# 253          NaN -2.000000e-08                Kwakisusi  Lake Victoria
# ...          ...           ...                      ...            ...
# 14649        NaN -2.000000e-08                   Husein  Lake Victoria
# 14676        NaN -2.000000e-08                Imalanota  Lake Victoria
# 14766        NaN -2.000000e-08                  Ofisini  Lake Victoria
# 14831        NaN -2.000000e-08             Kwa Masilili  Lake Victoria
# 14841        NaN -2.000000e-08                    Iguna  Lake Victoria
#
#        subvillage  ... payment_type  water_quality  quantity_group  \
# 21     Ibabachegu  ...      unknown        unknown         unknown
# 53         Center  ...      unknown        unknown             dry
# 168         Ilula  ...        other    soft (good)        seasonal
# 177        Mahaha  ...      unknown    soft (good)          enough
# 253     Nyamatala  ...    never pay    soft (good)    insufficient
# ...           ...  ...          ...            ...             ...
# 14649    Nyaweshi  ...    never pay    soft (good)    insufficient
# 14676   Busumabwi  ...        other    soft (good)          enough
# 14766    Madukani  ...    never pay    soft (good)    insufficient
# 14831    Solima A  ...    never pay          salty          enough
# 14841     Nyerere  ...      unknown    soft (good)          enough
#
#                      source           source_type  source_class  \
# 21             shallow well          shallow well   groundwater
# 53              machine dbh              borehole   groundwater
# 168    rainwater harvesting  rainwater harvesting       surface
# 177            shallow well          shallow well   groundwater
# 253            shallow well          shallow well   groundwater
# ...                     ...                   ...           ...
# 14649          shallow well          shallow well   groundwater
# 14676          shallow well          shallow well   groundwater
# 14766                  lake            river/lake       surface
# 14831          shallow well          shallow well   groundwater
# 14841          shallow well          shallow well   groundwater
#
#                    waterpoint_type quantity_columns_same waterpoint_type_same  \
# 21                       hand pump                  True                 True
# 53     communal standpipe multiple                  True                False
# 168             communal standpipe                  True                 True
# 177                          other                  True                 True
# 253                      hand pump                  True                 True
# ...                            ...                   ...                  ...
# 14649                    hand pump                  True                 True
# 14676                    hand pump                  True                 True
# 14766  communal standpipe multiple                  True                False
# 14831                    hand pump                  True                 True
# 14841                    hand pump                  True                 True
#
#        payment_same
# 21             True
# 53             True
# 168            True
# 177            True
# 253            True
# ...             ...
# 14649          True
# 14676          True
# 14766          True
# 14831          True
# 14841          True
#
# [2269 rows x 35 columns]

# %%
for df in dataframes:
    df['latitude'].replace(-2e-8, np.nan, inplace=True)

# %%
loc_df = training.copy() #Creating a copy of training dataframe to try out imputation performance

# %%
print("Longitude: ", (loc_df['longitude'].isnull()).sum())
print("Latitude: ", (loc_df['latitude'].isnull()).sum()) 
print((loc_df['gps_height'].isnull()).sum())
# Out:
# Longitude:  0
# Latitude:  0
# 0

# %% [markdown]
# Many of the water (1/3) pump have a GPS_height of 0. We could use a Maps API to estimate the gps_height based on the longitude and latitude of the water pump such as https://www.dcode.fr/earth-elevation

# %% [markdown]
# However, this would be expensive as there are a huge amount of values. Therefore, we are going to calculate the mean gps_height of similary located water pumps of the same: subvillage, region, lga, ward. Inspired by: "Hwang, Sungsoon & Webber-Ritchey, Kashica & Moxley, Elizabeth. (2022). Comparison of GPS imputation methods in environmental health research. Geospatial Health. 17. 10.4081/gh.2022.1081. "

# %%
mean_gps_height = loc_df.groupby(['subvillage', 'region', 'lga', 'ward'])['gps_height'].mean().reset_index(name='mean_gps_height')
mean_longitude = loc_df.groupby([ 'subvillage', 'region', 'lga', 'ward'])['longitude'].mean().reset_index(name='mean_longitude')
mean_latitude = loc_df.groupby(['subvillage', 'region', 'lga', 'ward'])['latitude'].mean().reset_index(name='mean_latitude')


loc_df = loc_df.merge(mean_gps_height, on=['subvillage', 'region', 'lga', 'ward'], how='left')
loc_df = loc_df.merge(mean_longitude, on=['subvillage', 'region', 'lga', 'ward'], how='left')
loc_df = loc_df.merge(mean_latitude, on=['subvillage', 'region', 'lga', 'ward'], how='left')

loc_df.loc[loc_df['gps_height'].isnull(), 'gps_height'] = loc_df['mean_gps_height']
loc_df.loc[loc_df['longitude'].isnull(), 'longitude'] = loc_df['mean_longitude']
loc_df.loc[loc_df['latitude'].isnull(), 'latitude'] = loc_df['mean_latitude']

loc_df.drop(columns=['mean_gps_height', 'mean_longitude', 'mean_latitude'], inplace=True)

# %%
print("Longitude: ", (loc_df['longitude'].isnull()).sum())
print("Latitude: ", (loc_df['latitude'].isnull()).sum()) 
print((loc_df['gps_height'].isnull()).sum())
check_impute_difference('longitude', X_train, loc_df)
check_impute_difference('gps_height', X_train, loc_df)
# Out:
# Longitude:  0
# Latitude:  0
# 0

# %% [markdown]
# So far, this has not been very useful as it has only imputed about 100 values of heights, and about 20 on longitude and latitude. Therefore, we will try doing a less granular approach for this imputation, but following the same idea: subvillage < ward < lga < region

# %% [markdown]
# ### Ward

# %%
mean_gps_height = loc_df.groupby(['region', 'lga', 'ward'])['gps_height'].mean().reset_index(name='mean_gps_height')
mean_longitude = loc_df.groupby(['region', 'lga', 'ward'])['longitude'].mean().reset_index(name='mean_longitude')
mean_latitude = loc_df.groupby(['region', 'lga', 'ward'])['latitude'].mean().reset_index(name='mean_latitude')


loc_df = loc_df.merge(mean_gps_height, on=['region', 'lga', 'ward'], how='left')
loc_df = loc_df.merge(mean_longitude, on=['region', 'lga', 'ward'], how='left')
loc_df = loc_df.merge(mean_latitude, on=['region', 'lga', 'ward'], how='left')

loc_df.loc[training['gps_height'].isnull(), 'gps_height'] = loc_df['mean_gps_height']
loc_df.loc[training['longitude'].isnull(), 'longitude'] = loc_df['mean_longitude']
loc_df.loc[training['latitude'].isnull(), 'latitude'] = loc_df['mean_latitude']

loc_df.drop(columns=['mean_gps_height', 'mean_longitude', 'mean_latitude'], inplace=True)
print("Longitude: ", (loc_df['longitude'].isnull()).sum())
print("Latitude: ", (loc_df['latitude'].isnull()).sum()) 
print((loc_df['gps_height'].isnull()).sum())
check_impute_difference('longitude', training, loc_df)
check_impute_difference('gps_height', training, loc_df)
# Out:
# Longitude:  0
# Latitude:  0
# 0

# %% [markdown]
# ### Local Government Area

# %%
mean_gps_height = loc_df.groupby(['region', 'lga'])['gps_height'].mean().reset_index(name='mean_gps_height')
mean_longitude = loc_df.groupby(['region', 'lga'])['longitude'].mean().reset_index(name='mean_longitude')
mean_latitude = loc_df.groupby(['region', 'lga'])['latitude'].mean().reset_index(name='mean_latitude')


loc_df = loc_df.merge(mean_gps_height, on=['region', 'lga'], how='left')
loc_df = loc_df.merge(mean_longitude, on=['region', 'lga'], how='left')
loc_df = loc_df.merge(mean_latitude, on=['region', 'lga'], how='left')

loc_df.loc[training['gps_height'].isnull(), 'gps_height'] = loc_df['mean_gps_height']
loc_df.loc[training['longitude'].isnull(), 'longitude'] = loc_df['mean_longitude']
loc_df.loc[training['latitude'].isnull(), 'latitude'] = loc_df['mean_latitude']

loc_df.drop(columns=['mean_gps_height', 'mean_longitude', 'mean_latitude'], inplace=True)
print("Longitude: ", (loc_df['longitude'].isnull()).sum())
print("Latitude: ", (loc_df['latitude'].isnull()).sum()) 
print((loc_df['gps_height'].isnull()).sum())
check_impute_difference('longitude', training, loc_df)
check_impute_difference('gps_height', training, loc_df)
# Out:
# Longitude:  0
# Latitude:  0
# 0

# %% [markdown]
# ### Region

# %%
mean_gps_height = loc_df.groupby(['region'])['gps_height'].mean().reset_index(name='mean_gps_height')
mean_longitude = loc_df.groupby(['region'])['longitude'].mean().reset_index(name='mean_longitude')
mean_latitude = loc_df.groupby(['region'])['latitude'].mean().reset_index(name='mean_latitude')


loc_df = loc_df.merge(mean_gps_height, on=['region'], how='left')
loc_df = loc_df.merge(mean_longitude, on=['region'], how='left')
loc_df = loc_df.merge(mean_latitude, on=['region'], how='left')

df.loc[training['gps_height'].isnull(), 'gps_height'] = loc_df['mean_gps_height']
df.loc[training['longitude'].isnull(), 'longitude'] = loc_df['mean_longitude']
df.loc[training['latitude'].isnull(), 'latitude'] = loc_df['mean_latitude']

loc_df.drop(columns=['mean_gps_height', 'mean_longitude', 'mean_latitude'], inplace=True)
print("Longitude: ", (loc_df['longitude'].isnull()).sum())
print("Latitude: ", (loc_df['latitude'].isnull()).sum()) 
print((loc_df['gps_height'].isnull()).sum())
check_impute_difference('longitude', training, loc_df)
check_impute_difference('gps_height', training, loc_df)
# Out:
# Longitude:  0
# Latitude:  0
# 0

# %%
mean_gps_height = training['gps_height'].mean()

loc_df.loc[loc_df['gps_height'].isnull(), 'gps_height'] = mean_gps_height

check_impute_difference('gps_height', training, loc_df)
log_imputation('gps_height', 'mean', final=False)
log_imputation('longitude', 'mean', final=False)
log_imputation('latitude', 'mean', final=False)
# Out:
# /tmp/ipykernel_83/1520250380.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '668.297239057239' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   loc_df.loc[loc_df['gps_height'].isnull(), 'gps_height'] = mean_gps_height

# %% [markdown]
# We have successfully imputed all values of longitude and latitude missing values. However, this last step of replacing all remaining values has completely changed the distribution of the data, which is not very optimal.

# %% [markdown]
# Another common technique of imputation is using Multiple Imputation by Chained Equations (MICE). Essentially, it imputes the data by going through a series of prediction regression models, creating several imputed datasets and combining the optimal output. (source)

# %% [markdown]
#  We will be using autoimpute, which is a library that helps us use common imputation techniques on our data.

# %%
df_train_mice = X_train.copy()
df_test_mice = X_test.copy()
df_test_values_mice = test_values.copy()


df_train_mice.drop(columns=['installer',  'subvillage', 'lga', 'ward', 'wpt_name', 'date_recorded', 'district_code', 'funder', 'permit'], inplace=True)
df_test_mice.drop(columns=['installer',  'subvillage', 'lga', 'ward', 'wpt_name', 'date_recorded', 'district_code', 'funder', 'permit'], inplace=True)
df_test_values_mice.drop(columns=['installer',  'subvillage', 'lga', 'ward', 'wpt_name', 'date_recorded', 'district_code', 'funder', 'permit'], inplace=True)

categories = [cname for cname in df_train_mice.columns if
                    df_train_mice[cname].dtype == "object"]




from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

for col in categories:
  encoder = LabelEncoder()
  df_train_mice[col] = encoder.fit_transform(df_train_mice[col])
  df_test_mice[col] = encoder.transform(df_test_mice[col])
  df_test_values_mice[col] = encoder.transform(df_test_values_mice[col])

imputer = IterativeImputer()

df_train_mice.iloc[:, :] = imputer.fit_transform(df_train_mice)
df_test_mice.iloc[:, :] = imputer.transform(df_test_mice)
df_test_values_mice.iloc[:, :] = imputer.transform(df_test_values_mice)

# %%
check_impute_difference('gps_height', X_train, df_train_mice)
check_impute_difference('longitude', X_train, df_train_mice)
check_impute_difference('latitude', X_train, df_train_mice)

# %% [markdown]
# This imputation technique has brought about better results than Mean imputation, therefore, we will choose to use the MICE imputation.

# %%
log_imputation('gps_height', 'mice', final=True)
log_imputation('longitude', 'mice', final=True)
log_imputation('latitude', 'mice', final=True)


X_train['gps_height'] = df_train_mice['gps_height']
X_train['longitude'] = df_train_mice['longitude']
X_train['latitude'] = df_train_mice['latitude']


X_test['gps_height'] = df_test_mice['gps_height']
X_test['longitude'] = df_test_mice['longitude']
X_test['latitude'] = df_test_mice['latitude']

test_values['gps_height'] = df_test_values_mice['gps_height']
test_values['longitude'] = df_test_values_mice['longitude']
test_values['latitude'] = df_test_values_mice['latitude']

# %% [markdown]
# <hr>

# %% [markdown]
# ### Population

# %% [markdown]
# Due to the nature of the Population column, the same imputation techniques that we used on the location could be trialed; it is a integer and has a high importance to do the dataset. We are going to assume that a population value of zero is null, because a water pump would usually be installed in an area with a population.

# %%
print("Number of null Populations: ", df['population'].isnull().sum())
# Out:
# Number of null Populations:  26834

# %%
pop_df = X_train.copy()

# %% [markdown]
# Logically, it would make sense that populations would be similar or identical in similar areas, therefore we are going to get the mean of the missing population values based on Geographical Locations as we did above for GPS information

# %%
#Subvillage
mean_population = pop_df.groupby(['subvillage', 'region', 'lga', 'ward'])['population'].mean().reset_index(name='mean_population')
pop_df = pop_df.merge(mean_population, on=['subvillage', 'region', 'lga', 'ward'], how='left')
pop_df.loc[pop_df['population'].isnull(), 'population'] = pop_df['mean_population']
pop_df.drop(columns=['mean_population'], inplace=True)

#ward
mean_population = pop_df.groupby(['region', 'lga', 'ward'])['gps_height'].mean().reset_index(name='mean_population')
pop_df = pop_df.merge(mean_population, on=['region', 'lga', 'ward'], how='left')
pop_df.loc[pop_df['population'].isnull(), 'population'] = pop_df['mean_population']
pop_df.drop(columns=['mean_population'], inplace=True)


#lga
mean_population = pop_df.groupby(['region', 'lga'])['gps_height'].mean().reset_index(name='mean_population')
pop_df = pop_df.merge(mean_population, on=['region', 'lga'], how='left')
pop_df.loc[pop_df['population'].isnull(), 'population'] = pop_df['mean_population']
pop_df.drop(columns=['mean_population'], inplace=True)

#region
mean_population = pop_df.groupby(['region'])['gps_height'].mean().reset_index(name='mean_population')
pop_df = pop_df.merge(mean_population, on=['region'], how='left')
pop_df.loc[pop_df['population'].isnull(), 'population'] = pop_df['mean_population']
pop_df.drop(columns=['mean_population'], inplace=True)

log_imputation('population', 'mean', final=False)

# %%
X_train['population'].plot(kind='kde', )
pop_df['population'].plot(kind='kde', style = "--")
labels = ['Original Dataset', 'Current Dataframe']
plt.legend(labels)
plt.xlabel('population')
plt.xlim(0, 2000)
plt.show()

# %% [markdown]
# This is not very convincing as the two datasets now have a very different distribution. We are now going to use the MICE as we did for the location

# %%
X_train['population'].plot(kind='kde', )
df_train_mice['population'].plot(kind='kde', style = "--")
labels = ['Original Population', 'Imputed Population']
plt.legend(labels)
plt.xlabel('population')
plt.xlim(0, 2000)
plt.show()

X_train['population'] = df_train_mice['population']
X_test['population'] = df_test_mice['population']
test_values['population'] = df_test_values_mice['population']
log_imputation('population', 'mice', final=True)

# %% [markdown]
# This is a lot more consistent with the original dataset, therefore we are going to choose the MICE Imputation once again.

# %% [markdown]
# ### Construction Year

# %%
print("Number of null Construction Years: ", X_train['construction_year'].isnull().sum())
# Out:
# Number of null Construction Years:  14451

# %% [markdown]
# Intuitively something like getting a mean of the construction year for such a high number of missing values does not seem very safe, therefore we are going to perform a MICE imputation once again from earlier

# %%
X_train['construction_year'].plot(kind='kde', )
df_train_mice['construction_year'].plot(kind='kde', style = "--")
labels = ['Original Dataset', 'Current Dataframe']
plt.legend(labels)
plt.xlabel('Construction Year')
plt.show()

# %%
X_train['construction_year'] = df_train_mice['construction_year']
X_test['construction_year'] = df_test_mice['construction_year']
test_values['construction_year'] = df_test_values_mice['construction_year']
log_imputation('construction_year', 'mice', final=True)

# %% [markdown]
# A last change is to use numerical data for our dataframe instead of a timestmap

# %%
for df in dataframes:
    df['year_recorded'] = df['date_recorded'].dt.year
    df['month_recorded'] = df['date_recorded'].dt.month
    df['day_recorded'] = df['date_recorded'].dt.day
    df = df.drop(columns=['date_recorded'])

# %% [markdown]
# <hr>

# %% [markdown]
# ### Data Cleaning / Imputing Progress

# %%
#Check on imputation Progress

coursework_progress
# Out:
#              Column Names  Taken Care Of Imputation Techniques Tried  \
# 0                      id          False                          []
# 1              amount_tsh           True                   [removal]
# 2           date_recorded          False                          []
# 3                  funder           True          [missing category]
# 4              gps_height           True                [mean, mice]
# 5               installer           True          [missing category]
# 6               longitude           True                [mean, mice]
# 7                latitude           True                [mean, mice]
# 8                wpt_name          False                          []
# 9             num_private           True                   [removal]
# 10                  basin          False                          []
# 11             subvillage          False                          []
# 12                 region          False                          []
# 13            region_code          False                          []
# 14          district_code          False                          []
# 15                    lga          False                          []
# 16                   ward          False                          []
# 17             population           True                [mean, mice]
# 18         public_meeting           True                   [removal]
# 19            recorded_by          False                          []
# 20      scheme_management          False                          []
# 21            scheme_name           True                   [removal]
# 22                 permit           True          [missing category]
# 23      construction_year           True                      [mice]
# 24        extraction_type          False                          []
# 25  extraction_type_group          False                          []
# 26  extraction_type_class          False                          []
# 27             management          False                          []
# 28       management_group          False                          []
# 29                payment           True                   [removal]
# 30           payment_type          False                          []
# 31          water_quality          False                          []
# 32          quality_group           True                   [removal]
# 33               quantity           True                   [removal]
# 34         quantity_group          False                          []
# 35                 source          False                          []
# 36            source_type          False                          []
# 37           source_class          False                          []
# 38        waterpoint_type          False                          []
# 39  waterpoint_type_group           True                   [removal]
# 40             functional          False                          []
#
#    Imputation Technique Used
# 0                       None
# 1                    removal
# 2                       None
# 3           missing category
# 4                       mice
# 5           missing category
# 6                       mice
# 7                       mice
# 8                       None
# 9                    removal
# 10                      None
# 11                      None
# 12                      None
# 13                      None
# 14                      None
# 15                      None
# 16                      None
# 17                      mice
# 18                   removal
# 19                      None
# 20                      None
# 21                   removal
# 22          missing category
# 23                      mice
# 24                      None
# 25                      None
# 26                      None
# 27                      None
# 28                      None
# 29                   removal
# 30                      None
# 31                      None
# 32                   removal
# 33                   removal
# 34                      None
# 35                      None
# 36                      None
# 37                      None
# 38                      None
# 39                   removal
# 40                      None

# %%
missing = round((X_train.isna().sum()) / len(df) * 100, 1)
missing = missing.sort_values(ascending=False)
missing.head(15)
# Out:
# subvillage       0.4
# date_recorded    0.0
# id               0.0
# funder           0.0
# gps_height       0.0
# longitude        0.0
# installer        0.0
# latitude         0.0
# wpt_name         0.0
# basin            0.0
# region           0.0
# region_code      0.0
# district_code    0.0
# lga              0.0
# ward             0.0
# dtype: float64

# %% [markdown]
# ## Encoding Categorical Features as Numeric + SVD

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import LabelEncoder

categorical_features = ['funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region', 'lga', 'ward', 'scheme_management', 'extraction_type', 'management', 'payment_type', 'water_quality', 'quantity_group', 'source', 'source_type', 'source_class', 'waterpoint_type']
numeric_features = ['gps_height', 'longitude', 'latitude', 'population', 'construction_year', 'year_recorded', 'day_recorded', 'month_recorded']

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])

svd = TruncatedSVD(n_components=100)  



pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('svd', svd)  # Using SVD instead of PCA
    
])

X_train_prepared = pipeline.fit_transform(X_train)
X_test_prepared = pipeline.transform(X_test)
# Out:
# 2024-05-06 08:50:26.707966: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-06 08:50:26.743333: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 08:50:26.743363: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 08:50:26.743391: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-06 08:50:26.750086: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-06 08:50:26.750544: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-06 08:50:27.829027: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print("Variance:", svd.explained_variance_ratio_)
# Out:
# Variance: [0.01089931 0.10762415 0.06969988 0.06501123 0.05246844 0.04741349
#  0.0420252  0.03958645 0.03274553 0.02499247 0.02426969 0.01974624
#  0.01642944 0.01380715 0.01246189 0.01091489 0.01065105 0.00872037
#  0.00862698 0.00751778 0.00735927 0.00676699 0.00658142 0.00613934
#  0.00605185 0.00573632 0.00539884 0.00506561 0.00481083 0.00468956
#  0.00450268 0.00419378 0.003943   0.00369421 0.00348235 0.0032763
#  0.00310788 0.00306454 0.00297733 0.00295159 0.00287125 0.00272213
#  0.00261984 0.00258145 0.00253596 0.00249648 0.00238456 0.00229896
#  0.00220538 0.00213548 0.00202794 0.00195694 0.00192703 0.00182761
#  0.00177591 0.00176211 0.00169188 0.00168601 0.00163164 0.00152999
#  0.00150015 0.00145491 0.00140172 0.00135852 0.00132948 0.00129557
#  0.0012901  0.00124072 0.00121893 0.00119422 0.00115719 0.00113997
#  0.00111789 0.00109959 0.00106589 0.00105018 0.00103678 0.00101768
#  0.00101188 0.00098245 0.00095949 0.00095715 0.00091106 0.00088614
#  0.00087376 0.000853   0.00083151 0.00081491 0.00080876 0.00079345
#  0.00077479 0.00075842 0.00075118 0.00074342 0.00072372 0.00070973
#  0.00068838 0.00068437 0.00066917 0.00065379]

# %% [markdown]
# # Applying Machine Learning algorithms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

#Confusion Matrix display
#Src: https://proclusacademy.com/blog/practical/confusion-matrix-accuracy-sklearn-seaborn/

def show_confusion_matrix(test, prediction, title):
    labels = test.unique()
    conf_matrix = confusion_matrix(y_test, prediction)
    ax = sns.heatmap(conf_matrix, annot=True, fmt='d', )
    ax.set_xlabel("Predicted", fontsize=14, labelpad=20)
    ax.xaxis.set_ticklabels(labels)
    ax.set_ylabel("Actual", fontsize=14, labelpad=20)
    ax.yaxis.set_ticklabels(labels)
    ax.set_title(title, fontsize=14, pad=20)
    plt.show()

# %% [markdown]
# ## Classification

# %% [markdown]
# ### 1] Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


# Define the logistic regression model
lr = LogisticRegression()

# Define the hyperparameters grid
param_dist = {
    'C': [0.1, 1, 10],  
    'penalty': ['l2'],  
    'solver': ['lbfgs'],  
    'max_iter': [200, 300, 400]
}

# Perform grid search with cross-validation
random_search = RandomizedSearchCV(estimator=lr, param_distributions=param_dist,
                                   n_iter=10, cv=3, verbose=2, random_state=42, n_jobs=-1)

random_search.fit(X_train_prepared, y_train)

# Print the best hyperparameters and model score
print("Best Hyperparameters:", random_search.best_params_)
print("Best Model Score:", random_search.best_score_)
("Best Model Score:", random_search.best_score_)
# Out:
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 11
#       9 # Perform grid search with cross-validation
#      10 grid_search = GridSearchCV(lr, param_grid, cv=5, scoring='accuracy')
# ---> 11 grid_search.fit(X_train_prepared, y_train)
#      13 # Print the best hyperparameters and model score
#      14 print("Best Hyperparameters:", grid_search.best_params_)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1228, in LogisticRegression.fit(self, X, y, sample_weight)
#    1222     if effective_n_jobs(self.n_jobs) != 1:
#    1223         warnings.warn(
#    1224             "'n_jobs' > 1 does not have any effect when"
#    1225             " 'solver' is set to 'liblinear'. Got 'n_jobs'"
#    1226             " = {}.".format(effective_n_jobs(self.n_jobs))
#    1227         )
# -> 1228     self.coef_, self.intercept_, self.n_iter_ = _fit_liblinear(
#    1229         X,
#    1230         y,
#    1231         self.C,
#    1232         self.fit_intercept,
#    1233         self.intercept_scaling,
#    1234         self.class_weight,
#    1235         self.penalty,
#    1236         self.dual,
#    1237         self.verbose,
#    1238         self.max_iter,
#    1239         self.tol,
#    1240         self.random_state,
#    1241         sample_weight=sample_weight,
#    1242     )
#    1243     return self
#    1245 if solver in ["sag", "saga"]:
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/svm/_base.py:1230, in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#    1227 sample_weight = _check_sample_weight(sample_weight, X, dtype=np.float64)
#    1229 solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
# -> 1230 raw_coef_, n_iter_ = liblinear.train_wrap(
#    1231     X,
#    1232     y_ind,
#    1233     sp.issparse(X),
#    1234     solver_type,
#    1235     tol,
#    1236     bias,
#    1237     C,
#    1238     class_weight_,
#    1239     max_iter,
#    1240     rnd.randint(np.iinfo("i").max),
#    1241     epsilon,
#    1242     sample_weight,
#    1243 )
#    1244 # Regarding rnd.randint(..) in the above signature:
#    1245 # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#    1246 # on 32-bit platforms, we can't get to the UINT_MAX limit that
#    1247 # srand supports
#    1248 n_iter_max = max(n_iter_)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter = 1000)

lr.fit(X_train_prepared,y_train)

lr_pred= lr.predict(X_test_prepared)

print("Logistic Regression Classifier: ")
print(classification_report(y_test, lr_pred))

show_confusion_matrix(y_test, lr_pred, "Logicistic Regression Results")
# Out:
# Logistic Regression Classifier:
#                          precision    recall  f1-score   support
#
#              functional       0.72      0.90      0.80      9678
# functional needs repair       0.50      0.08      0.14      1295
#          non functional       0.79      0.64      0.71      6847
#
#                accuracy                           0.74     17820
#               macro avg       0.67      0.54      0.55     17820
#            weighted avg       0.73      0.74      0.72     17820

# %% [markdown]
# ### 2] Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestClassifier()



param_dist = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_dist, 
                                   n_iter=10, cv=3, verbose=2, random_state=42, n_jobs=-1)

random_search.fit(X_train_prepared, y_train)

print("Best Hyperparameters:", random_search.best_params_)
print("Best Model Score:", random_search.best_score_)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  56.9s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  55.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  54.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  29.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  28.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  28.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  56.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  55.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  54.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 1.8min
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 1.8min
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 1.8min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  54.0s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  54.4s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  55.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.9min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 2.0min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.9min
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 1.7min
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 1.7min
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 1.8min
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 4.1min
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 4.5min
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 3.7min
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 6 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.75971621 0.78831169 0.75995671        nan 0.79064454 0.78997114
#  0.76053391 0.78855219 0.78867244        nan]
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 30}
# Best Model Score: 0.7906445406445407

# %%
from sklearn.ensemble import RandomForestClassifier


classifier = RandomForestClassifier()

classifier.fit(X_train_prepared, y_train)

predictions = classifier.predict(X_test_prepared)

print("Random Forest Classifier:")
print(classification_report(y_test, predictions))


show_confusion_matrix(y_test, predictions, "Random Forest Results")
# Out:
# Random Forest Classifier:
#                          precision    recall  f1-score   support
#
#              functional       0.80      0.87      0.83      9678
# functional needs repair       0.51      0.29      0.37      1295
#          non functional       0.81      0.77      0.79      6847
#
#                accuracy                           0.79     17820
#               macro avg       0.70      0.64      0.66     17820
#            weighted avg       0.78      0.79      0.78     17820

# %% [markdown]
# ### 3] Support Vector Machine(SVM)

# %%
from sklearn.svm import SVC

#Initialize the SVM classifier
svm_classifier = SVC()

#Train the classifier
svm_classifier.fit(X_train_prepared, y_train)

#Make predictions on the test set
svm_pred = svm_classifier.predict(X_test_prepared)

#Evaluate the classifier
print("Support Vector Machine Classifier:")
print(classification_report(y_test, svm_pred))
# Out:
# Support Vector Machine Classifier:
#                          precision    recall  f1-score   support
#
#              functional       0.75      0.93      0.83      9678
# functional needs repair       0.64      0.16      0.25      1295
#          non functional       0.85      0.69      0.76      6847
#
#                accuracy                           0.78     17820
#               macro avg       0.75      0.59      0.61     17820
#            weighted avg       0.78      0.78      0.76     17820

# %% [markdown]
# ### 4] Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train_prepared, y_train)
dt_predictions = dt_classifier.predict(X_test_prepared)

print("Decision tree classifier: ")
print(classification_report(y_test, dt_predictions))

show_confusion_matrix(y_test, dt_predictions, "Decision Tree Results")
# Out:
# Decision tree classifier:
#                          precision    recall  f1-score   support
#
#              functional       0.78      0.78      0.78      9678
# functional needs repair       0.34      0.35      0.34      1295
#          non functional       0.73      0.74      0.73      6847
#
#                accuracy                           0.73     17820
#               macro avg       0.62      0.62      0.62     17820
#            weighted avg       0.73      0.73      0.73     17820

# %% [markdown]
# ### 5] Multilayer Perceptron Neural Network (MLP)

# %%
from sklearn.neural_network import MLPClassifier

# Initialize the MLP classifier
mlp_classifier = MLPClassifier(hidden_layer_sizes=(100, ), max_iter=100, activation='relu', solver='adam', random_state=1)

# Train the classifier
mlp_classifier.fit(X_train_prepared, y_train)

# Make predictions on the test set
mlp_pred = mlp_classifier.predict(X_test_prepared)

# Evaluate the classifier
print("Multilayer Perceptron (MLP) Classifier:")
print(classification_report(y_test, mlp_pred))
show_confusion_matrix(y_test, mlp_pred, "Multilayer Perceptron (MLP) Classifier Results")
# Out:
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Multilayer Perceptron (MLP) Classifier:
#                          precision    recall  f1-score   support
#
#              functional       0.80      0.86      0.83      9678
# functional needs repair       0.50      0.29      0.37      1295
#          non functional       0.79      0.78      0.79      6847
#
#                accuracy                           0.78     17820
#               macro avg       0.70      0.64      0.66     17820
#            weighted avg       0.78      0.78      0.78     17820

# %% [markdown]
# ### 6] K-Nearest Neighbour (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

#Initialize the KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (K) as needed

#Training the classifier
knn_classifier.fit(X_train_prepared, y_train)

#Make predictions on the test set
knn_pred = knn_classifier.predict(X_test_prepared)

#Evaluate
print("K-Nearest Neighbors (KNN) Classifier:")
print(classification_report(y_test, knn_pred))
show_confusion_matrix(y_test, knn_pred, "Multilayer Perceptron (MLP) Classifier Results")
# Out:
# K-Nearest Neighbors (KNN) Classifier:
#                          precision    recall  f1-score   support
#
#              functional       0.78      0.87      0.82      9678
# functional needs repair       0.49      0.32      0.38      1295
#          non functional       0.81      0.72      0.76      6847
#
#                accuracy                           0.77     17820
#               macro avg       0.69      0.64      0.65     17820
#            weighted avg       0.77      0.77      0.77     17820

# %% [markdown]
# ### 7] Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize the Gaussian Naive Bayes classifier
gnb_classifier = GaussianNB()

# Train the classifier
gnb_classifier.fit(X_train_prepared, y_train)

# Make predictions on the test set
gnb_pred = gnb_classifier.predict(X_test_prepared)

# Evaluate the classifier
print("Gaussian Naive Bayes Classifier:")
print(classification_report(y_test, gnb_pred))
show_confusion_matrix(y_test, gnb_pred, "Gaussian Naive Bayes Classifier Results")
# Out:
# Gaussian Naive Bayes Classifier:
#                          precision    recall  f1-score   support
#
#              functional       0.71      0.72      0.72      9678
# functional needs repair       0.26      0.32      0.29      1295
#          non functional       0.66      0.63      0.64      6847
#
#                accuracy                           0.65     17820
#               macro avg       0.54      0.55      0.55     17820
#            weighted avg       0.66      0.65      0.66     17820

# %% [markdown]
# ### 8] Neural Network

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41580 entries, 30018 to 1323
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     41580 non-null  int64
#  1   funder                 41580 non-null  object
#  2   gps_height             41580 non-null  float64
#  3   installer              41580 non-null  object
#  4   longitude              41580 non-null  float64
#  5   latitude               41580 non-null  float64
#  6   wpt_name               41578 non-null  object
#  7   basin                  41580 non-null  object
#  8   subvillage             41319 non-null  object
#  9   region                 41580 non-null  object
#  10  region_code            41580 non-null  int64
#  11  district_code          41580 non-null  int64
#  12  lga                    41580 non-null  object
#  13  ward                   41580 non-null  object
#  14  population             41580 non-null  float64
#  15  recorded_by            41580 non-null  object
#  16  scheme_management      41580 non-null  object
#  17  permit                 41580 non-null  object
#  18  construction_year      41580 non-null  float64
#  19  extraction_type        41580 non-null  object
#  20  extraction_type_group  41580 non-null  object
#  21  extraction_type_class  41580 non-null  object
#  22  management             41580 non-null  object
#  23  management_group       41580 non-null  object
#  24  payment_type           41580 non-null  object
#  25  water_quality          41580 non-null  object
#  26  quantity_group         41580 non-null  object
#  27  source                 41580 non-null  object
#  28  source_type            41580 non-null  object
#  29  source_class           41580 non-null  object
#  30  waterpoint_type        41580 non-null  object
#  31  year_recorded          41580 non-null  int32
#  32  month_recorded         41580 non-null  int32
#  33  day_recorded           41580 non-null  int32
# dtypes: float64(5), int32(3), int64(3), object(23)
# memory usage: 10.6+ MB

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /shared-libs/python3.11/py/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (1.26.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.11/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical


y_train_nn = to_categorical(y_train_encoded)
y_test_nn = to_categorical(y_test_encoded)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year_recorded'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/utils/__init__.py:447, in _get_column_indices(X, key)
#     446 for col in columns:
# --> 447     col_idx = all_columns.get_loc(col)
#     448     if not isinstance(col_idx, numbers.Integral):
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#
# KeyError: 'year_recorded'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[242], line 18
#      10 numeric_features = ['gps_height', 'longitude', 'latitude', 'population', 'construction_year', 'year_recorded', 'day_recorded', 'month_recorded']
#      12 preprocessor = ColumnTransformer(
#      13     transformers=[
#      14         ('num', StandardScaler(), numeric_features),
#      15         ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
#      16     ])
# ---> 18 X_train_nn = preprocessor.fit_transform(X_train)
#      19 X_test_nn = preprocessor.transform(X_test, )
#      21 X_train_nn = X_train_nn.toarray() if hasattr(X_train_nn, "toarray") else X_train_nn
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:751, in ColumnTransformer.fit_transform(self, X, y)
#     749 self._check_n_features(X, reset=True)
#     750 self._validate_transformers()
# --> 751 self._validate_column_callables(X)
#     752 self._validate_remainder(X)
#     754 result = self._fit_transform(X, y, _fit_transform_one)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:459, in ColumnTransformer._validate_column_callables(self, X)
#     457         columns = columns(X)
#     458     all_columns.append(columns)
# --> 459     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     461 self._columns = all_columns
#     462 self._transformer_to_input_indices = transformer_to_input_indices
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/utils/__init__.py:455, in _get_column_indices(X, key)
#     452             column_indices.append(col_idx)
#     454     except KeyError as e:
# --> 455         raise ValueError("A given column is not a column of the dataframe") from e
#     457     return column_indices
#     458 else:
#
# ValueError: A given column is not a column of the dataframe

# %%
import os

if not os.environ.get("DEEPNOTE"):
    model = Sequential([
        Dense(64, activation='relu', input_dim=X_train_prepared.shape[1]),
        Dense(32, activation='relu'),
        Dense(3, activation='softmax')  # Change to 3 neurons, one for each class
    ])


    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


    history = model.fit(X_train_prepared, y_train_nn, epochs=10, batch_size=32, validation_split=0.1)

    test_loss, test_acc = model.evaluate(X_test_prepared, y_test_nn)
    print("Test accuracy:", test_acc)
else:
    print("This is a deepnote environment. Skipping Neural networks")
# Out:
# This is a deepnote environment. Skipping Neural networks

# %% [markdown]
# ## Evaluation Metrics

# %% [markdown]
# ### K-fold cross validation

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=aa0cdc8d-bec1-43a1-9a51-9c5b6130c78f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
